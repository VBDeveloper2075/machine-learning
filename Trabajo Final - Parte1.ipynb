# %% [markdown]
# **Ejercicio práctico final**
# ---
# Parte 1
# ---
#
#
# Resolver el siguiente ejercicio de programación
# El empleado llamado Juan cobró 300 dólares por mes desde enero a junio, 500 dólares de julio a octubre, y 700 dólares por mes en noviembre y en diciembre.
#
#
#
# En base al escenario propuesto, se le solicita a los estudiantes que creen un pequeño programa que calcule el sueldo promedio del empleado Juan. Además, se debe indicar sí Juan se encuentra cobrando un sueldo bajo, normal o mejor de lo normal, considerando las siguientes pautas:
#
#
#
# a. Sueldo bajo: por debajo de 300 dólares.
#
# b. Sueldo normal:  entre 300 a 900.
#
# c. Sueldo mejor de lo normal: más de 900 dólares.
#
#
#
# Tip: se debe utilizar estructuras condicionales.

# %%
# Definir los montos de sueldo por mes
sueldo_enero_junio = 300
sueldo_julio_octubre = 500
sueldo_noviembre_diciembre = 700

# Calcular el sueldo promedio
sueldo_promedio = (sueldo_enero_junio * 6 + sueldo_julio_octubre * 4 + sueldo_noviembre_diciembre * 2) / 12

# Determinar la categoría de sueldo
categoria_sueldo = ""
if sueldo_promedio < 300:
    categoria_sueldo = "Sueldo bajo"
elif sueldo_promedio <= 900:
    categoria_sueldo = "Sueldo normal"
else:
    categoria_sueldo = "Sueldo mejor de lo normal"

# Imprimir los resultados
print("El sueldo promedio de Juan es:", sueldo_promedio)
print("Categoría de sueldo:", categoria_sueldo)
# Out:
# El sueldo promedio de Juan es: 433.3333333333333
# Categoría de sueldo: Sueldo normal

# %% [markdown]
# ---
#
# Parte 2
# Realizar una ingesta de datos de un archivo formato .csv utilizando la librería de Pandas
# Para este apartado, deberás poder ingestar un archivo en Jupyter Notebook en un formato de tipo .csv.
#
# ---
#
# Resulta importante aclarar que, la elección del archivo queda a criterio propio, sin embargo a continuación se proporciona un link de interés para la descarga gratuita de datasets.
#
# Enlace: https://www.kaggle.com/datasets(opens in a new tab)
#
# Importante: en caso de no disponer de una cuenta en Kaggle, será requerido realizar el registro correspondiente en la página.

# %% [markdown]
# ---
# Parte 3
#
#
# ---
#
#
# Responder la siguiente consigna:
# Mencioná y explicá brevemente un caso de éxito de aplicación de ML en la empresa.
#
# Aclaraciones generales: la resolución del presente apartado debe contener como mínimo 300 palabras y un máximo de 1000.

# %% [markdown]
# El Machine Learning (ML) es una rama de la Inteligencia Artificial que permite a las máquinas aprender de los datos y mejorar su rendimiento sin necesidad de programación explícita. Esta tecnología tiene un enorme potencial para transformar los negocios y ofrecer ventajas competitivas en diversos sectores. A continuación, se presenta un ejemplo de cómo una empresa ha utilizado el ML para optimizar sus procesos y aumentar sus beneficios.
#
# La empresa en cuestión es Uber, la plataforma de movilidad que conecta a conductores y pasajeros mediante una aplicación móvil. Uber utiliza el ML para resolver varios desafíos, como la estimación de precios, la asignación de viajes, la detección de fraudes, la seguridad vial y la satisfacción del cliente.
#
# Uno de los casos más destacados es el uso del ML para predecir la demanda de viajes en tiempo real y ajustar los precios dinámicamente. Uber utiliza un sistema llamado "surge pricing" que aumenta o disminuye el precio del viaje según la oferta y la demanda en cada zona y momento. El objetivo es incentivar a los conductores a ir a las zonas con más demanda y equilibrar el mercado.
#
# Para implementar este sistema, Uber utiliza algoritmos de ML que analizan una gran cantidad de datos históricos y en tiempo real, como el número de viajes, el clima, los eventos, el tráfico, etc. Estos algoritmos son capaces de detectar patrones y tendencias en la demanda y predecir su evolución futura con gran precisión. Así, Uber puede ajustar los precios en función de la demanda esperada y maximizar sus ingresos.
#
# El uso del ML para el "surge pricing" ha supuesto un gran éxito para Uber, ya que le ha permitido aumentar su eficiencia operativa, su rentabilidad y su cuota de mercado. Según un estudio realizado por investigadores de la Universidad de Chicago, el "surge pricing" ha incrementado el número de viajes en un 15.8% y los ingresos totales en un 19.7%. Además, ha mejorado la experiencia de los usuarios, ya que ha reducido el tiempo de espera y ha garantizado la disponibilidad del servicio.
#
# Pero este no es el único ejemplo de cómo el ML puede aportar valor a las empresas y ayudarlas a resolver problemas complejos. El ML también se utiliza para otros fines, como:
#
# *La asignación de viajes: Uber utiliza algoritmos de ML para asignar el conductor más adecuado a cada pasajero, teniendo en cuenta factores como la distancia, el tiempo, la calificación, las preferencias, etc. Esto permite reducir los costes operativos y mejorar la calidad del servicio.
# La detección de fraudes: Uber utiliza algoritmos de ML para detectar y prevenir actividades fraudulentas tanto por parte de los conductores como de los pasajeros. Por ejemplo, Uber puede identificar si un conductor está manipulando su ubicación o si un pasajero está usando una tarjeta robada.
# *La seguridad vial: Uber utiliza algoritmos de ML para monitorizar el comportamiento de los conductores y proporcionarles retroalimentación en tiempo real. Por ejemplo, Uber puede alertar a los conductores si detecta que están conduciendo de forma agresiva o distraída.
# *La satisfacción del cliente: Uber utiliza algoritmos de ML para medir y mejorar la satisfacción del cliente. Por ejemplo, Uber puede enviar encuestas personalizadas a los usuarios después de cada viaje u ofrecer incentivos como descuentos y promociones.
# Estos son solo algunos de los muchos ejemplos de cómo el machine learning está revolucionando el mundo empresarial y que ofrece grandes oportunidades para innovar y crecer. El ML es una tecnología que está cambiando la forma de hacer negocios y que requiere una adaptación constante por parte de las empresas.
